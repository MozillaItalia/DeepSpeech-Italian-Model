# %%
# !git clone https://github.com/eziolotta/DeepSpeech-Italian-Model.git
# Out:
# Cloning into 'DeepSpeech-Italian-Model'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 3552 (delta 65), reused 82 (delta 44), pack-reused 3436
# Receiving objects: 100% (3552/3552), 39.26 MiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (567/567), done.

# %%
# %cd DeepSpeech-Italian-Model
# Out:
# /content/DeepSpeech-Italian-Model

# %%
# !git checkout fix_importers
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
# %cd /content/DeepSpeech-Italian-Model/MITADS-Speech/
# !pip install -r requirements.txt
# Out:
# /content/DeepSpeech-Italian-Model/MITADS-Speech
# ...
#      |████████████████████████████████| 1.4MB 8.2MB/s
# ...
#      |████████████████████████████████| 61kB 5.9MB/s
# ...
#      |████████████████████████████████| 102kB 10.6MB/s
# ...
#      |████████████████████████████████| 102kB 9.8MB/s
# ...
#   Created wheel for zhon: filename=zhon-1.1.5-cp36-none-any.whl size=84293 sha256=29de4beb2a20469675542e475a44e74fe2a85c098736474134b57913e6dfb38e
#   Stored in directory: /root/.cache/pip/wheels/0e/93/5a/ad2f403c359ba996e33c21bf18611d921413df9740ede2fcf4
# ...
#   Created wheel for hanzidentifier: filename=hanzidentifier-1.0.2-cp36-none-any.whl size=4731 sha256=41a6ebc62b55a94b515ffbb81c67bd2184125409d0294afc342cc8db9545a82e
#   Stored in directory: /root/.cache/pip/wheels/79/ef/cb/0b668ccd8c0d9dd94e59bfed1f9404ea50b2bace3b37c86351
# ...
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7667 sha256=a4c1ed2dc136a35359d06f321d53b6e31d1927e5c071668811490fdc804d72f2
# ...

# %%
# !apt install sox
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 15 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# ...

# %%
ls
# Out:
# assets/                   evalita_importer.py   mspka_importer.py  utils/
# corpora_collector_old.py  lablita_importer.py   README.md
# corpora_collector.py      m-ailabs_importer.py  requirements.txt
# corpora_importer.py       mls_importer.py       siwis_importer.py

# %%
##Set up Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## set the folders for the download of the datasets and for the output of the generated csvs. 
# For generated csv will be created sub folders with the name of the corpora

DOWNLOAD_DIR="/content/drive/My Drive/datasets/speech_datasets/download_dataset"
CSV_OUTPUT_DIR="/content/drive/My Drive/datasets/speech_datasets/mitads-speech_0.1"

# %%
# !python evalita_importer.py  -d "$DOWNLOAD_DIR"  -o "$CSV_OUTPUT_DIR"
# Out:
# No path "/content/drive/My Drive/datasets/speech_datasets/mitads-speech_01/evalita2009" - creating ...
# No archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/evalita2009srt.zip" - downloading...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.evalita.it:80
# DEBUG:urllib3.connectionpool:http://www.evalita.it:80 "GET /sites/evalita.fbk.eu/files/doc2009/evalita2009srt.zip HTTP/1.1" 200 458139057
# Progress |##################################################### |  98% completedNo directory /content/drive/My Drive/datasets/speech_datasets/download_dataset/evalita2009srt - extracting archive...
# Filter audio file and parse transcript...
# Converting audio files to wav 16000hz Mono
# Progress |######################################################| 100% completed
#
# Writing CSV files
# Wrote 5863 entries
# Progress |######################################################| 100% completed
# ...

# %%
# !python siwis_importer.py  -d "$DOWNLOAD_DIR"  -o "$CSV_OUTPUT_DIR"
# Out:
# No path "/content/drive/My Drive/datasets/speech_datasets/mitads-speech_0.1/siwis" - creating ...
# No archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/siwis_latest.zip" - downloading...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): phonogenres.unige.ch:443
# DEBUG:urllib3.connectionpool:https://phonogenres.unige.ch:443 "GET /downloads/siwis_latest.zip HTTP/1.1" 200 5533285635
# Progress |######################################################| 100% completedNo directory /content/drive/My Drive/datasets/speech_datasets/download_dataset/siwis_database - extracting archive...
# Filter audio file and parse transcript...
# /usr/local/lib/python3.6/dist-packages/charset_normalizer/normalizer.py:362: UserWarning: Trying to detect encoding from a tiny portion of (19) bytes.
#   warn('Trying to detect encoding from a tiny portion of ({}) bytes.'.format(len(sequences)))
# ...

# %%
## CLEAR FREE DISK space : remove ONLY downloaded archive (not remove unzip folder)

# %%
# !python mspka_importer.py  -d "$DOWNLOAD_DIR"  -o "$CSV_OUTPUT_DIR"
# Out:
# No path "/content/drive/My Drive/datasets/speech_datasets/mitads-speech_0.1/mspka" - creating ...
# No archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/cnz_1.0.0.zip" - downloading...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.mspkacorpus.it:80
# DEBUG:urllib3.connectionpool:http://www.mspkacorpus.it:80 "GET /MSPKA_data/session1/cnz_1.0.0.zip HTTP/1.1" 200 244495194
# Progress |######################################################| 100% completedNo directory /content/drive/My Drive/datasets/speech_datasets/download_dataset/cnz_1.0.0 - extracting archive...
# Filter audio file and parse transcript...
# Converting audio files to wav 16000hz Mono
# Progress |######################################################| 100% completed
#
# Writing CSV files
# Wrote 666 entries
# No archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/lls_1.0.0.zip" - downloading...
# ...

# %%
# !python m-ailabs_importer.py -d "$DOWNLOAD_DIR"  -o "$CSV_OUTPUT_DIR"
# Out:
# No path "/content/drive/My Drive/datasets/speech_datasets/mitads-speech_0.1/m-ailabs" - creating ...
# No archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/it_IT.tgz" - downloading...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.caito.de:443
# DEBUG:urllib3.connectionpool:https://www.caito.de:443 "GET /data/Training/stt_tts/it_IT.tgz HTTP/1.1" 200 10172839115
# Progress |######################################################| 100% completedNo directory /content/drive/My Drive/datasets/speech_datasets/download_dataset/it_IT - extracting archive...
# Filter audio file and parse transcript...
# Converting audio files to wav 16000hz Mono
# Progress |######################################################| 100% completed
#
# Writing CSV files
# Wrote 73405 entries
# Progress |######################################################| 100% completed
# Progress |######################################################| 100% completed

# %%
## CLEAR FREE DISK space : remove ONLY downloaded archive (not remove unzip folder)

# %%
# !python mls_importer.py -d "$DOWNLOAD_DIR"  -o "$CSV_OUTPUT_DIR"
# Out:
# Found archive "/content/drive/My Drive/datasets/speech_datasets/download_dataset/mls_italian.tar.gz" - not downloading.
# Found directory /content/drive/My Drive/datasets/speech_datasets/download_dataset/mls_italian - not extracting it from archive.
# Filter audio file and parse transcript...
# Converting audio files to wav 16000hz Mono
# Progress |########################                              |  46% completed

# %%
## CLEAR FREE DISK space : remove ONLY downloaded archive (not remove unzip folder)
